# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Ron\Documents\Scrape\FOR PORTFOLIO\Cleaning of Credit Cards\uncleaned\credit_customers.csv")

# %%
df
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   checking_status         1000 non-null   object
#  1   duration                1000 non-null   float64
#  2   credit_history          1000 non-null   object
#  3   purpose                 1000 non-null   object
#  4   credit_amount           1000 non-null   float64
#  5   savings_status          1000 non-null   object
#  6   employment              1000 non-null   object
#  7   installment_commitment  1000 non-null   float64
#  8   personal_status         1000 non-null   object
#  9   other_parties           1000 non-null   object
#  10  residence_since         1000 non-null   float64
#  11  property_magnitude      1000 non-null   object
#  12  age                     1000 non-null   float64
#  13  other_payment_plans     1000 non-null   object
# ...

# %%
df.describe()
# Out:
#           duration  credit_amount  installment_commitment  residence_since  \
# count  1000.000000    1000.000000             1000.000000      1000.000000
# mean     20.903000    3271.258000                2.973000         2.845000
# std      12.058814    2822.736876                1.118715         1.103718
# min       4.000000     250.000000                1.000000         1.000000
# 25%      12.000000    1365.500000                2.000000         2.000000
# 50%      18.000000    2319.500000                3.000000         3.000000
# 75%      24.000000    3972.250000                4.000000         4.000000
# max      72.000000   18424.000000                4.000000         4.000000
#
#                age  existing_credits  num_dependents
# count  1000.000000       1000.000000     1000.000000
# mean     35.546000          1.407000        1.155000
# std      11.375469          0.577654        0.362086
# min      19.000000          1.000000        1.000000
# ...

# %%
df.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
df = df.drop(columns = ['checking_status', 'duration', 'credit_history', 'purpose','employment',
       'installment_commitment', 'personal_status', 'other_parties','other_payment_plans','num_dependents'])

# %%
df.head()
# Out:
#    credit_amount    savings_status  residence_since property_magnitude   age  \
# 0         1169.0  no known savings              4.0        real estate  67.0
# 1         5951.0              <100              2.0        real estate  22.0
# 2         2096.0              <100              3.0        real estate  49.0
# 3         7882.0              <100              4.0     life insurance  45.0
# 4         4870.0              <100              4.0  no known property  53.0
#
#     housing  existing_credits                 job own_telephone  \
# 0       own               2.0             skilled           yes
# 1       own               1.0             skilled          none
# 2       own               1.0  unskilled resident          none
# 3  for free               1.0             skilled          none
# 4  for free               2.0             skilled          none
#
#   foreign_worker class
# 0            yes  good
# 1            yes   bad
# 2            yes  good
# ...

# %%
df["job"].unique()
# Out:
# array(['skilled', 'unskilled resident', 'high qualif/self emp/mgmt',
#        'unemp/unskilled non res'], dtype=object)

# %%
df.columns
# Out:
# Index(['credit_amount', 'savings_status', 'residence_since',
#        'property_magnitude', 'age', 'housing', 'existing_credits', 'job',
#        'own_telephone', 'foreign_worker', 'class'],
#       dtype='object')

# %%
df = df.drop(columns = "savings_status")

# %%
df.head()
# Out:
#    credit_amount  residence_since property_magnitude   age   housing  \
# 0         1169.0              4.0        real estate  67.0       own
# 1         5951.0              2.0        real estate  22.0       own
# 2         2096.0              3.0        real estate  49.0       own
# 3         7882.0              4.0     life insurance  45.0  for free
# 4         4870.0              4.0  no known property  53.0  for free
#
#    existing_credits                 job own_telephone foreign_worker class
# 0               2.0             skilled           yes            yes  good
# 1               1.0             skilled          none            yes   bad
# 2               1.0  unskilled resident          none            yes  good
# 3               1.0             skilled          none            yes  good
# 4               2.0             skilled          none            yes   bad

# %%
df.isna().sum()
# Out:
# credit_amount         0
# residence_since       0
# property_magnitude    0
# age                   0
# housing               0
# existing_credits      0
# job                   0
# own_telephone         0
# foreign_worker        0
# class                 0
# dtype: int64

# %%
df.columns = [column.capitalize() for column in df.columns]

# %%
df.columns
# Out:
# Index(['Credit_amount', 'Residence_since', 'Property_magnitude', 'Age',
#        'Housing', 'Existing_credits', 'Job', 'Own_telephone', 'Foreign_worker',
#        'Class'],
#       dtype='object')

# %%
df.head()
# Out:
#    Credit_amount  Residence_since Property_magnitude   Age   Housing  \
# 0         1169.0              4.0        real estate  67.0       own
# 1         5951.0              2.0        real estate  22.0       own
# 2         2096.0              3.0        real estate  49.0       own
# 3         7882.0              4.0     life insurance  45.0  for free
# 4         4870.0              4.0  no known property  53.0  for free
#
#    Existing_credits                 Job Own_telephone Foreign_worker Class
# 0               2.0             skilled           yes            yes  good
# 1               1.0             skilled          none            yes   bad
# 2               1.0  unskilled resident          none            yes  good
# 3               1.0             skilled          none            yes  good
# 4               2.0             skilled          none            yes   bad

# %%
df["Class"] = df["Class"].apply(lambda x: 1 if x == "good" else 0)

# %%
df["Own_telephone"] = df["Own_telephone"].apply(lambda x: 1 if x == "yes" else 0)

# %%
df["Foreign_worker"] = df["Foreign_worker"].apply(lambda x: 1 if x == "yes" else 0)

# %%
df.head(5)
# Out:
#    Credit_amount  Residence_since Property_magnitude   Age   Housing  \
# 0         1169.0              4.0        real estate  67.0       own
# 1         5951.0              2.0        real estate  22.0       own
# 2         2096.0              3.0        real estate  49.0       own
# 3         7882.0              4.0     life insurance  45.0  for free
# 4         4870.0              4.0  no known property  53.0  for free
#
#    Existing_credits                 Job  Own_telephone  Foreign_worker  Class
# 0               2.0             skilled              1               1      1
# 1               1.0             skilled              0               1      0
# 2               1.0  unskilled resident              0               1      1
# 3               1.0             skilled              0               1      1
# 4               2.0             skilled              0               1      0

# %%
df["Existing_credits"]=df["Existing_credits"].astype(int)

# %%
df["Residence_since"]=df["Residence_since"].astype(int)

# %%
df["Housing"]=df["Housing"].str.replace("for free", "free")

# %%
df.head()
# Out:
#    Credit_amount  Residence_since Property_magnitude   Age Housing  \
# 0         1169.0                4        real estate  67.0     own
# 1         5951.0                2        real estate  22.0     own
# 2         2096.0                3        real estate  49.0     own
# 3         7882.0                4     life insurance  45.0    free
# 4         4870.0                4  no known property  53.0    free
#
#    Existing_credits                 Job  Own_telephone  Foreign_worker  Class
# 0                 2             skilled              1               1      1
# 1                 1             skilled              0               1      0
# 2                 1  unskilled resident              0               1      1
# 3                 1             skilled              0               1      1
# 4                 2             skilled              0               1      0

# %%
df["Job"].unique()
# Out:
# array(['skilled', 'unskilled resident', 'high qualif/self emp/mgmt',
#        'unemp/unskilled non res'], dtype=object)

# %%
df.head()
# Out:
#    Credit_amount  Residence_since Property_magnitude   Age Housing  \
# 0         1169.0                4        real estate  67.0     own
# 1         5951.0                2        real estate  22.0     own
# 2         2096.0                3        real estate  49.0     own
# 3         7882.0                4     life insurance  45.0    free
# 4         4870.0                4  no known property  53.0    free
#
#    Existing_credits                 Job  Own_telephone  Foreign_worker  Class
# 0                 2             skilled              1               1      1
# 1                 1             skilled              0               1      0
# 2                 1  unskilled resident              0               1      1
# 3                 1             skilled              0               1      1
# 4                 2             skilled              0               1      0
